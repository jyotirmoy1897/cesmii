# %% [markdown]
# **Copyright © 2023, Abhishek Hanchate, Satish T.S. Bukkapatnam, and Smart Manufacturing Advanced Research Team, Texas A&M University, All rights reserved.**

# %%
__author__ = "Abhishek Hanchate"
__copyright__ = "Copyright (C) 2023 Abhishek Hanchate"
__version__ = "1.0"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import io
from google.colab import files
datapath = '/content/drive/My Drive/Ph. D. Research/CESMII Project/UTRGV-DL/'

# %%
# Load libraries
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras import models
from keras import layers
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
# Set random seed
np.random.seed(0)

# %%
import tensorflow as tf
import os
import sys
stderr = sys.stderr
sys.stderr = open(os.devnull, 'w')
import keras
sys.stderr = stderr
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.metrics import BinaryAccuracy
from keras.callbacks import LearningRateScheduler

# %%
import matplotlib as mpl
import os
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 18
plt.rcParams['axes.linewidth'] = 2
import plotly.offline as py
import plotly.graph_objs as go
import cv2
import glob
import time
import datetime
import math

# %%
import numpy as np
from scipy import signal
import scipy.io.wavfile as wav
from numpy.lib import stride_tricks
import matplotlib.pyplot as plt

""" short time fourier transform of audio signal """
def stft(sig, frameSize, overlapFac=0.5, window=np.hanning):
    win = window(frameSize)
    hopSize = int(frameSize - np.floor(overlapFac * frameSize))
    
    # zeros at beginning (thus center of 1st window should be for sample nr. 0)
    samples = np.append(np.zeros(np.int64(np.floor(frameSize/2.0))), sig)    
    # cols for windowing
    cols = np.int64(np.ceil( (len(samples) - frameSize) / float(hopSize)) + 1)
    # zeros at end (thus samples can be fully covered by frames)
    samples = np.append(samples, np.zeros(frameSize))
    
    frames = stride_tricks.as_strided(
            samples, shape=(cols, frameSize),
            strides=(samples.strides[0]*hopSize, samples.strides[0])).copy()
    frames *= win
    
    return np.fft.rfft(frames)    
    
""" scale frequency axis logarithmically """    
def logscale_spec(spec, sr=44100, factor=20.):
    timebins, freqbins = np.shape(spec)

    scale = np.linspace(0, 1, freqbins) ** factor
    scale *= (freqbins-1)/max(scale)
    scale = np.unique(np.round(scale))
    scale = np.int64(scale)
    
    # create spectrogram with new freq bins
    newspec = np.complex128(np.zeros([timebins, len(scale)]))
    for i in range(0, len(scale)):
        if i == len(scale)-1:
            newspec[:,i] = np.sum(spec[:,scale[i]:], axis=1)
        else:        
            newspec[:,i] = np.sum(spec[:,scale[i]:scale[i+1]], axis=1)
    
    # list center freq of bins
    allfreqs = np.abs(np.fft.fftfreq(freqbins*2, 1./sr)[:freqbins+1])
    freqs = []
    for i in range(0, len(scale)):
        if i == len(scale)-1:
            freqs += [np.mean(allfreqs[scale[i]:])]
        else:
            freqs += [np.mean(allfreqs[scale[i]:scale[i+1]])]
    
    return newspec, freqs

""" plot spectrogram"""
def plotstft(samples, samplerate, binsize=2**10, 
        plotpath=None, colormap="jet", plot_artifacts=True):
    
    font = {'family': 'Calibri',
        'color':  'black',
        'weight': 'bold',
        'size': 18,
        }   

    s = stft(samples, binsize)
    
    sshow, freq = logscale_spec(s, factor=1.0, sr=samplerate)
    ims = 20.*np.log10(np.abs(sshow)/10e-6) # amplitude to decibel
    #ims = (np.abs(sshow))**(1/100) # amplitude to decibel
    
    timebins, freqbins = np.shape(ims)
    
    plt.figure(figsize=(8, 6))
    plt.imshow(np.transpose(ims), origin="lower", 
            aspect="auto", cmap=colormap, interpolation="none", vmin=25, vmax=125)
    # vmin = -0, vmax = 100
    if not plot_artifacts:
      plt.axis('off')
    else:
      plt.colorbar()
      plt.xlabel("Time (Seconds)", fontdict = font)
      plt.ylabel("Frequency (Hz)", fontdict = font)
      plt.xlim([0, timebins-1])
      plt.ylim([0, freqbins])

      xlocs = np.float32(np.linspace(0, timebins-1, 5))
      plt.xticks(xlocs, ["%.02f" % l for l in 
          ((xlocs*len(samples)/timebins)+(0.5*binsize))/samplerate], fontsize = 24, fontweight = 'bold')

      ylocs = np.int16(np.round(np.linspace(0, freqbins-1, 10)))
      plt.yticks(ylocs, ["%.02f" % freq[i] for i in ylocs], fontsize = 24, fontweight = 'bold')
    
    if plotpath:
        plt.savefig(plotpath, bbox_inches="tight")
    else:
        plt.show()
    plt.clf()

# %%
import pandas as pd
data11 = pd.read_excel(datapath + 'CESMII220512/Experiment 1-Trial 1.xlsx')
print(data11.head(10))
# Out:
#       Timestamp 2022-05-12 12:43:47
# 0      Interval            0.000006
# 1  Channel name             Input 0
# 2          Unit                   V
# 3             0           -0.010345
# 4      0.000006           -0.012548
# 5      0.000013           -0.011299
# 6      0.000019           -0.009293
# 7      0.000025           -0.006958
# 8      0.000031           -0.001794
# 9      0.000037           -0.001696

# %%
import pandas as pd
data11 = pd.read_csv(datapath + 'CESMII_UTRGV_50kHz/CESMII221028VwHaL/CESMII221028VwHaL 01-05.csv')
print(data11.head(10))
# Out:
#       Timestamp   10/28/2022 2:52:56 PM
# 0      Interval                   2E-05
# 1  Channel name                 Input 0
# 2          Unit                       V
# 3             0    0.007581044614208248
# 4         2E-05    0.013077439348260562
# 5         4E-05  -0.0083611408315788852
# 6         6E-05   -0.007128735137425745
# 7         8E-05   0.0054193927761266632
# 8        0.0001    0.012055927186728389
# 9       0.00012   0.0020978299592506714
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning:
#
# Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
#rater = pd.read_pickle(datapath + 'Experiment 1-4 rates.pkl')

# %%
#print(rater)

# %%
len(data11)
# Out:
# 8843813

# %%
print(data11.head(20))

# %%
len(data11) / 160000
# Out:
# 55.27383125

# %%
print(pd.DataFrame(data11).head(20))

# %%
dff = data11.loc[3:]   # dff = data11.loc[3:]  # dff = data11.loc[15:]
dff = dff.iloc[:, 1]   # dff = dff.iloc[:, 1]  # dff = dff.iloc[:, 1]

# %%
dff = list(dff) # For new datasets>

# %%
len(dff)
# Out:
# 4717301

# %%
len(dff) / 160000
# Out:
# 6.553575

# %%
rate = data11.iloc[0, 1]
rate
# Out:
# '2E-05'

# %%
rate = 1 / rate
rate

# %%
font = {'family': 'Calibri',
        'color':  'black',
        'weight': 'bold',
        'size': 18,
        }

# %%
from matplotlib.pyplot import figure
import matplotlib.font_manager
font = {'family': 'Calibri',
        'color':  'black',
        'weight': 'bold',
        'size': 18,
        }   
figure(figsize=(8, 6)) # 25, 13
plt.plot(dff, linewidth = 2)
plt.title('Data Signal - Time domain', fontdict = font)
plt.xlabel('Time (Seconds)', fontdict = font)
plt.ylabel('Amplitude (Volts)', fontdict = font)
plt.xticks(fontsize = 16, fontweight = 'bold')
plt.yticks(fontsize = 16, fontweight = 'bold')
plt.grid()
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 2.5
plt.rcParams["figure.figsize"] = (8, 6)
plt.tight_layout()
#plt.ylim([-0.2, 0.2])
#plt.xlim([0, 6.5])
#plt.savefig(datapath + 'acc_timedomain.png', dpi = 330)

# %%
plt.plot(dff)

# %%
160000 / 1250
# Out:
# 128.0

# %%
dff1 = []
for i in range(0, len(dff), 128):
    dff1.append(dff.iloc[i])

# %%
len(dff1)
# Out:
# 8192

# %%
8192 / 1250
# Out:
# 6.5536

# %%
1048575 / 160000
# Out:
# 6.55359375

# %%
dff1 = dff1[:2000]

# %%
dff1 = dff1 - np.mean(dff1)

# %%
dff = np.asarray(dff, dtype='float64')

# %%
dff = dff - np.mean(dff)

# %%
f = plt.figure(figsize=(8, 6)) 
pxx,  freq, t, cax = plt.specgram(dff, Fs=50000, cmap=plt.cm.rainbow) # 160000
_ = plt.axis('on')
plt.title('New sample data - Spectrogram', fontdict = font)
plt.xlabel('Time (Seconds)', fontdict = font)
plt.ylabel('Frequency (Hz)', fontdict = font)
plt.xticks(fontsize = 16, fontweight = 'bold')
plt.yticks(fontsize = 16, fontweight = 'bold')
plt.grid()
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 2.5
plt.rcParams["figure.figsize"] = (8, 6)
plt.tight_layout()
#f.colorbar(cax).set_label('Intensity [dB]', fontdict = font)
#f.colorbar(cax).ax.tick_params(labelsize=16, labelweight = 'bold') 
_ = plt.ylim([0, 25000])
_ = plt.xlim([15, 21.5])
#_ = plt.close()
#plt.axis('off')

# %%
dff = dff[:160000]

# %%
f_acc, t_acc, Sxx_acc = signal.spectrogram(dff, fs = 160000, window = signal.windows.hamming(160000), nperseg = 160000, noverlap = 80000, nfft = 160000, axis = 0)

# %%
print(Sxx_acc.shape)
# Out:
# (80001, 12)

# %%
final_acc = pd.DataFrame(Sxx_acc).iloc[:,0:12].mean(axis = 1)

# %%
figure(figsize=(8, 6))
plt.plot(final_acc, linewidth = 2)
plt.title("Data Signal - Frequency domain", fontdict = font)
plt.xlabel("Frequency (Hz)", fontdict=font)
plt.ylabel("Amplitude", fontdict=font)
plt.xticks(np.arange(0, 80000, 20000))
plt.xticks(fontsize = 16, fontweight = 'bold')
plt.yticks(fontsize = 16, fontweight = 'bold')
plt.grid()
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 2.5
plt.rcParams["figure.figsize"] = (8, 6)

plt.ylim(0,  0.025e-05)
plt.xlim(0, 80000)
# Out:
# (0.0, 80000.0)

# %%
import pandas as pd
data31 = pd.read_excel(datapath + 'CESMII220517/Experiment 3-Trial 1.xlsx')
print(data31.head(10))
# Out:
#       Timestamp 2022-05-17 12:22:48
# 0      Interval            0.000006
# 1  Channel name             Input 0
# 2          Unit                   V
# 3             0           -0.002682
# 4      0.000006            0.003138
# 5      0.000013            0.009617
# 6      0.000019            0.008203
# 7      0.000025            0.012511
# 8      0.000031            0.007808
# 9      0.000037            0.003369

# %%
f = plt.figure()
_ = plt.specgram(dff, Fs=160000, cmap="rainbow") # 160000
_ = plt.axis('on')
_ = plt.ylim([25000, 30000])

f = plt.figure()
_ = plt.specgram(dff, Fs=160000, cmap="rainbow") # 160000
_ = plt.axis('on')
_ = plt.ylim([20000, 25000])

f = plt.figure()
_ = plt.specgram(dff, Fs=160000, cmap="rainbow") # 160000
_ = plt.axis('on')
_ = plt.ylim([15000, 20000])

f = plt.figure()
_ = plt.specgram(dff, Fs=160000, cmap="rainbow") # 160000
_ = plt.axis('on')
_ = plt.ylim([10000, 15000])

f = plt.figure()
_ = plt.specgram(dff, Fs=160000, cmap="rainbow") # 160000
_ = plt.axis('on')
_ = plt.ylim([5000, 10000])

f = plt.figure()
_ = plt.specgram(dff, Fs=160000, cmap="rainbow") # 160000
_ = plt.axis('on')
_ = plt.ylim([0, 5000])


#_ = plt.xlim([0, 1])

# %%
dff3 = data31.loc[3:]
dff3 = dff3.iloc[:, 1]

# %%
dff3 = dff3 - np.mean(dff3)

# %%
f = plt.figure()
_ = plt.specgram(dff3, Fs=160000, cmap="rainbow")
_ = plt.axis('on')
#_ = plt.ylim([0, 5000])
_ = plt.xlim([0, 1])

# %%
plotstft(dff, 160000, binsize=2**10, plot_artifacts=False)

# %%
#%% Datasets 1
starttime = time.time()
rates = []
datasets = list()
for i in range(1, 21):
    data = pd.read_excel(datapath + f'CESMII220522/CESMII220922VwHaL{i}.xlsx')
    df = data11.loc[15:] 
    df = df.iloc[:, 1]
    rate = data.iloc[5, 1]
    rate = 1 / rate
    datasets.append(df)
    rates.append(rate)
endtime = time.time()
print("\n")
print("It took", endtime - starttime, "seconds for", i, "files")
# Out:
# It took 7.348631381988525 seconds for 20 files

# %%
pd.DataFrame(datasets).to_pickle(datapath + 'CESMII220512/Experiment 1-Trial datasets.pkl')

# %%
pd.DataFrame(rates).to_pickle(datapath + 'CESMII220512/Experiment 1-Trial rates.pkl')

# %%
#%% Datasets 2
starttime = time.time()
for i in range(1, 21):
    data = pd.read_excel(datapath + f'CESMII220516/Experiment 2-Trial {i}.xlsx')
    df = data.loc[3:]
    df = df.iloc[:, 1]
    rate = data.iloc[4, 0]
    rate = 1 / rate
    datasets.append(df)
    rates.append(rate)
endtime = time.time()
print("\n")
print("It took", endtime - starttime, "seconds for", i, "files")
# Out:
# It took 728.9871361255646 seconds for 20 files

# %%
#%% Datasets 3
starttime = time.time()
for i in range(1, 21):
    data = pd.read_excel(datapath + f'CESMII220517/Experiment 3-Trial {i}.xlsx')
    df = data.loc[3:]
    df = df.iloc[:, 1]
    rate = data.iloc[4, 0]
    rate = 1 / rate
    datasets.append(df)
    rates.append(rate)
endtime = time.time()
print("\n")
print("It took", endtime - starttime, "seconds for", i, "files")
# Out:
# It took 790.913990020752 seconds for 20 files

# %%
#%% Datasets 4
starttime = time.time()
for i in range(1, 21):
    data = pd.read_excel(datapath + f'CESMII220518/Experiment 4-Trial {i}.xlsx')
    df = data.loc[3:]
    df = df.iloc[:, 1]
    rate = data.iloc[4, 0]
    rate = 1 / rate
    datasets.append(df)
    rates.append(rate)
endtime = time.time()
print("\n")
print("It took", endtime - starttime, "seconds for", i, "files")
# Out:
# It took 788.4124045372009 seconds for 20 files

# %%
pd.DataFrame(datasets).to_pickle(datapath + 'Experiment 1-4 datasets.pkl')
pd.DataFrame(rates).to_pickle(datapath + 'Experiment 1-4 rates.pkl')

# %%
# Loading Pickle Files - 29th Sept 2022
data = pd.read_pickle(datapath + 'Experiment 1-4 datasets.pkl')
rates = pd.read_pickle(datapath + 'Experiment 1-4 rates.pkl')

# %%
data

# %%
for i in range(len(data)):
  mean = np.mean(data.iloc[i, :])
  data.iloc[i, :] = data.iloc[i, :] - mean

# %%
datasets = data

# %%
datasets.iloc[0, :]
# Out:
# 3         -0.010439
# 4         -0.012642
# 5         -0.011392
# 6         -0.009386
# 7         -0.007051
#              ...
# 1048570   -0.006755
# 1048571   -0.002579
# 1048572    0.000710
# 1048573    0.009951
# 1048574    0.010378
# Name: 2022-05-12 12:43:47, Length: 1048572, dtype: float64

# %%
datasets[0]

# %%
for i in range(1, 21):
    signal_data = datasets[i-1]
    signal_data = signal_data - np.mean(signal_data)
    f = plt.figure()
    _ = plt.specgram(signal_data, Fs=1250, cmap="rainbow")
    _ = plt.axis('on')

# %%
for i in range(1, 81): # 81
    signal_data = datasets.iloc[i-1, :]

    # plotstft(signal_data, 160000, binsize=2**13, plotpath = datapath + f'Spectrograms/spectro_{i}.png', \
    #                 colormap="jet", plot_artifacts=False)

    f = plt.figure()
    _ = plt.specgram(signal_data, Fs=160000, cmap="rainbow")
    _ = plt.ylim([0, 10000])
    _ = plt.axis('off')
    f.savefig(datapath + f'Spectrograms_Freq_Ranged/spectro_(0-10000)_{i}.png')
    _ = plt.close()

    f = plt.figure()
    _ = plt.specgram(signal_data, Fs=160000, cmap="rainbow")
    _ = plt.ylim([10000, 20000])
    _ = plt.axis('off')
    f.savefig(datapath + f'Spectrograms_Freq_Ranged/spectro_(10000-20000)_{i}.png')
    _ = plt.close()

    f = plt.figure()
    _ = plt.specgram(signal_data, Fs=160000, cmap="rainbow")
    _ = plt.ylim([20000, 30000])
    _ = plt.axis('off')
    f.savefig(datapath + f'Spectrograms_Freq_Ranged/spectro_(20000-30000)_{i}.png')
    _ = plt.close()

    f = plt.figure()
    _ = plt.specgram(signal_data, Fs=160000, cmap="rainbow")
    _ = plt.ylim([30000, 40000])
    _ = plt.axis('off')
    f.savefig(datapath + f'Spectrograms_Freq_Ranged/spectro_(30000-40000)_{i}.png')
    _ = plt.close()

    f = plt.figure()
    _ = plt.specgram(signal_data, Fs=160000, cmap="rainbow")
    _ = plt.ylim([40000, 50000])
    _ = plt.axis('off')
    f.savefig(datapath + f'Spectrograms_Freq_Ranged/spectro_(40000-50000)_{i}.png')
    _ = plt.close()

    f = plt.figure()
    _ = plt.specgram(signal_data, Fs=160000, cmap="rainbow")
    _ = plt.ylim([50000, 60000])
    _ = plt.axis('off')
    f.savefig(datapath + f'Spectrograms_Freq_Ranged/spectro_(50000-60000)_{i}.png')
    _ = plt.close()

    f = plt.figure()
    _ = plt.specgram(signal_data, Fs=160000, cmap="rainbow")
    _ = plt.ylim([60000, 70000])
    _ = plt.axis('off')
    f.savefig(datapath + f'Spectrograms_Freq_Ranged/spectro_(60000-70000)_{i}.png')
    _ = plt.close()
    
    f = plt.figure()
    _ = plt.specgram(signal_data, Fs=160000, cmap="rainbow")
    _ = plt.ylim([70000, 80000])
    _ = plt.axis('off')
    f.savefig(datapath + f'Spectrograms_Freq_Ranged/spectro_(70000-80000)_{i}.png')
    _ = plt.close()

# %%
# Skip 38 and 39 since issues with Spectrogram
X = []
for i in range(1, 38): # 81  # (40, 81)  # 
  img = cv2.imread(datapath + f"Spectrograms/spectro_(70000-80000)_{i}.png") 
  X.append(img)
print(X)

# %%
y_data = pd.read_excel(datapath + 'CESMII220512/CESMIIExperiment 1-Calibration.xlsx')
y1 = y_data.Ra
y1 = y1.dropna()
print(pd.DataFrame(y1))

# %%
y_data = pd.read_excel(datapath + 'CESMII220516/CESMIIExperiment 2-Calibration..xlsx')
y2 = y_data.Ra
y2 = y2.dropna()
print(pd.DataFrame(y2))

# %%
y_data = pd.read_excel(datapath + 'CESMII220517/CESMIIExperiment 3-Calibration (2).xlsx')
y3 = y_data.Ra
y3 = y3.dropna()
print(pd.DataFrame(y3))

# %%
y_data = pd.read_excel(datapath + 'CESMII220518/CESMIIExperiment 4-Calibration.xlsx')
y4 = y_data.Ra
y4 = y4.dropna()
print(pd.DataFrame(y4))

# %%
y = y1.append(y2)
y = y.append(y3)
y = y.append(y4)
y

# %%
yy = y.reset_index()
yy

# %%
df_transpose = yy.T

# %%
df_transpose.pop(37)
# Out:
# index    34.0000
# Ra        0.0585
# Name: 37, dtype: float64

# %%
df_transpose.pop(38)
# Out:
# index    36.00000
# Ra        0.08025
# Name: 38, dtype: float64

# %%
yyy = df_transpose.T
yyy

# %%
y = yyy.Ra
y

# %%
training_images = np.array(X)

# %%
from skimage.transform import resize
width, height = 512, 512
resized = [resize(i, (width, height)) for i in X]
training_images = np.array(resized)

# %%
training_images[0]

# %%
from matplotlib import pyplot as plt
plt.imshow(training_images[0], interpolation='nearest')
plt.show()

# %%
X_backup = X
X_backup

# %%
immgg = X[0]
immgg.shape
# Out:
# (288, 432, 3)

# %%
cropp = immgg[180:240, :, :]
cropp.shape
# Out:
# (60, 432, 3)

# %%
Y = []
for k in range(len(X)):
  smp = X[k]
  smpp = smp[180:240, 60:380, :]
  smp_img = smpp.astype("float32") / 255.0
  #lab = cv2.cvtColor(smp_img, cv2.COLOR_BGR2HSV) # BGR2HSV
  Y.append(smp_img)
print(Y)

# %%
# smp_img = training_images[0].astype("float32") / 255.0
# lab = cv2.cvtColor(smp_img, cv2.COLOR_BGR2LAB)

# %%
from matplotlib import pyplot as plt
plt.imshow(cropp, interpolation='nearest')
plt.show()

# %%
from matplotlib import pyplot as plt
plt.imshow(Y[2], interpolation='nearest')
plt.show()

# %%
for i in range(1, 79): # 81
    signal_data = Y[i-1]
    f = plt.figure()
    _ = plt.imshow(signal_data, interpolation='nearest')
    _ = plt.axis('off')
    f.savefig(datapath + f'29thSept_CNN_Model_2_Aug_Specs/spectro_{i}.png')

# %%
training_images = np.array(Y) # np.array(Y)

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Valid, y_Train, y_Valid = train_test_split(training_images, y, test_size=0.15)

# %%
import tensorflow as tf
import keras
from keras import layers
from keras import models
from keras import utils
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import Activation
from keras.regularizers import l2
from keras import datasets
from keras.callbacks import LearningRateScheduler
from keras.callbacks import History
from keras import losses
from sklearn.utils import shuffle

# %%
print(X_Train)
print(y_Train)
print(X_Valid)
print(y_Valid)

# %%
X_Train.shape[1:]
# Out:
# (60, 320, 3)

# %%
print(type(X_Train))
print(type(y_Train))
print(type(X_Valid))
print(type(y_Valid))
# Out:
# <class 'list'>
# <class 'pandas.core.series.Series'>
# <class 'list'>
# <class 'pandas.core.series.Series'>

# %%
print(len(X_Train))
print(len(y_Train))
print(len(X_Valid))
print(len(y_Valid))
# Out:
# 66
# 66
# 12
# 12

# %%
X_Train.shape
# Out:
# (66, 60, 320, 3)

# %%
y_Train.shape
# Out:
# (62,)

# %%
X_Train_backup = X_Train
X_Valid_backup = X_Valid
y_Train_backup = y_Train
y_Valid_backup = y_Valid

# %%
# Multiple Inputs
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate

# first input model
visible1 = Input(shape=(64,64,1))
conv11 = Conv2D(32, kernel_size=4, activation='relu')(visible1)
pool11 = MaxPooling2D(pool_size=(2, 2))(conv11)
conv12 = Conv2D(16, kernel_size=4, activation='relu')(pool11)
pool12 = MaxPooling2D(pool_size=(2, 2))(conv12)
flat1 = Flatten()(pool12)

# second input model
visible2 = Input(shape=(32,32,3))
conv21 = Conv2D(32, kernel_size=4, activation='relu')(visible2)
pool21 = MaxPooling2D(pool_size=(2, 2))(conv21)
conv22 = Conv2D(16, kernel_size=4, activation='relu')(pool21)
pool22 = MaxPooling2D(pool_size=(2, 2))(conv22)
flat2 = Flatten()(pool22)

# merge input models
merge = concatenate([flat1, flat2])

# interpretation model
hidden1 = Dense(10, activation='relu')(merge)
hidden2 = Dense(10, activation='relu')(hidden1)
output = Dense(1, activation='sigmoid')(hidden2)
model = Model(inputs=[visible1, visible2], outputs=output)

# summarize layers
print(model.summary())

# %%
# Initialize Neural Network model
# define the model
m = Sequential()
m.add(Dense(64, activation="relu", input_shape=X_Train.shape[1:]))
m.add(Dense(32, activation='relu'))
m.add(layers.Flatten())
m.add(Dense(8, activation='relu'))
m.add(Dense(1, activation='linear'))
#m.summary()

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation=tf.nn.relu, input_shape=X_Train.shape[1:]))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
# model.add(tf.keras.layers.Conv2D(16, kernel_size=(2, 2), activation=tf.nn.relu, input_shape=X_Train.shape[1:]))
# model.add(tf.keras.layers.MaxPooling2D(pool_size=(1,1)))
model.add(tf.keras.layers.Flatten()) 
#model.add(tf.keras.layers.Dense(128, activation = tf.nn.relu, input_shape=X_Train.shape[1:]))
#model.add(tf.keras.layers.Dense(128, activation = tf.nn.relu,))
model.add(tf.keras.layers.Dense(64, activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(1, activation = 'linear'))

# %%
from keras import optimizers
adam = tf.keras.optimizers.Adam(learning_rate = 0.001, beta_1 = 0.99, beta_2 = 0.999, amsgrad = False)
model.compile(loss='mae', optimizer=adam, metrics=['mse'])
history = model.fit(X_Train, y_Train, epochs = 500, batch_size = 16, validation_data=(X_Valid, y_Valid), shuffle=False, verbose=1)
# Out:
# Epoch 1/500
# 5/5 [==============================] -
500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0136 - mse: 2.9873e-04 - val_loss: 0.0164 - val_mse: 3.5156e-04
# Epoch 32/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0136 - mse: 3.1928e-04 - val_loss: 0.0152 - val_mse: 3.1457e-04
# Epoch 33/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0132 - mse: 2.9444e-04 - val_loss: 0.0120 - val_mse: 2.1753e-04
# Epoch 34/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0127 - mse: 2.8140e-04 - val_loss: 0.0117 - val_mse: 1.9590e-04
# Epoch 35/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0127 - mse: 3.0585e-04 - val_loss: 0.0119 - val_mse: 1.8854e-04
# Epoch 36/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0132 - mse: 3.1823e-04 - val_loss: 0.0103 - val_mse: 1.5191e-04
# Epoch 37/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0131 - mse: 3.0712e-04 - val_loss: 0.0105 - val_mse: 1.7513e-04
# Epoch 38/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0134 - mse: 3.3148e-04 - val_loss: 0.0100 - val_mse: 1.4273e-04
# Epoch 39/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0133 - mse: 3.3469e-04 - val_loss: 0.0107 - val_mse: 1.5490e-04
# Epoch 40/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0142 - mse: 3.5030e-04 - val_loss: 0.0105 - val_mse: 1.4954e-04
# Epoch 41/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0127 - mse: 3.0006e-04 - val_loss: 0.0098 - val_mse: 1.4099e-04
# Epoch 42/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0124 - mse: 2.8628e-04 - val_loss: 0.0097 - val_mse: 1.4662e-04
# Epoch 43/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0119 - mse: 2.8273e-04 - val_loss: 0.0110 - val_mse: 1.7692e-04
# Epoch 44/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0129 - mse: 3.0879e-04 - val_loss: 0.0135 - val_mse: 2.6293e-04
# Epoch 45/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0136 - mse: 3.2282e-04 - val_loss: 0.0124 - val_mse: 2.2342e-04
# Epoch 46/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0123 - mse: 2.6453e-04 - val_loss: 0.0113 - val_mse: 1.7541e-04
# Epoch 47/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0125 - mse: 2.6609e-04 - val_loss: 0.0115 - val_mse: 1.7695e-04
# Epoch 48/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0122 - mse: 2.6544e-04 - val_loss: 0.0117 - val_mse: 2.0410e-04
# Epoch 49/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0123 - mse: 2.8068e-04 - val_loss: 0.0136 - val_mse: 2.7253e-04
# Epoch 50/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0132 - mse: 3.0507e-04 - val_loss: 0.0131 - val_mse: 2.5248e-04
# Epoch 51/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0125 - mse: 2.7193e-04 - val_loss: 0.0113 - val_mse: 1.8411e-04
# Epoch 52/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0119 - mse: 2.5015e-04 - val_loss: 0.0112 - val_mse: 1.6266e-04
# Epoch 53/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0120 - mse: 2.5325e-04 - val_loss: 0.0109 - val_mse: 1.5662e-04
# Epoch 54/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0118 - mse: 2.5508e-04 - val_loss: 0.0106 - val_mse: 1.6472e-04
# Epoch 55/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0123 - mse: 2.7224e-04 - val_loss: 0.0108 - val_mse: 1.7761e-04
# Epoch 56/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0125 - mse: 2.7569e-04 - val_loss: 0.0099 - val_mse: 1.3959e-04
# Epoch 57/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0117 - mse: 2.4710e-04 - val_loss: 0.0092 - val_mse: 1.2036e-04
# Epoch 58/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0117 - mse: 2.4728e-04 - val_loss: 0.0091 - val_mse: 1.1853e-04
# Epoch 59/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0117 - mse: 2.5132e-04 - val_loss: 0.0086 - val_mse: 1.0833e-04
# Epoch 60/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0118 - mse: 2.4883e-04 - val_loss: 0.0085 - val_mse: 1.0680e-04
# Epoch 61/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0116 - mse: 2.3719e-04 - val_loss: 0.0090 - val_mse: 1.1420e-04
# Epoch 62/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0116 - mse: 2.3663e-04 - val_loss: 0.0088 - val_mse: 1.1222e-04
# Epoch 63/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0115 - mse: 2.2919e-04 - val_loss: 0.0087 - val_mse: 1.1613e-04
# Epoch 64/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0114 - mse: 2.2137e-04 - val_loss: 0.0093 - val_mse: 1.2667e-04
# Epoch 65/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0113 - mse: 2.2019e-04 - val_loss: 0.0099 - val_mse: 1.4293e-04
# Epoch 66/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0115 - mse: 2.2537e-04 - val_loss: 0.0106 - val_mse: 1.6191e-04
# Epoch 67/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0114 - mse: 2.1746e-04 - val_loss: 0.0104 - val_mse: 1.5554e-04
# Epoch 68/500
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0114 - mse: 2.1121e-04 - val_loss: 0.0104 - val_mse: 1.5556e-04
# Epoch 69/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0112 - mse: 2.1034e-04 - val_loss: 0.0104 - val_mse: 1.6239e-04
# Epoch 70/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0113 - mse: 2.1504e-04 - val_loss: 0.0103 - val_mse: 1.6466e-04
# Epoch 71/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0110 - mse: 2.0378e-04 - val_loss: 0.0101 - val_mse: 1.4362e-04
# Epoch 72/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0111 - mse: 1.9708e-04 - val_loss: 0.0102 - val_mse: 1.4489e-04
# Epoch 73/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0114 - mse: 2.0968e-04 - val_loss: 0.0099 - val_mse: 1.4271e-04
# Epoch 74/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0109 - mse: 2.0580e-04 - val_loss: 0.0104 - val_mse: 1.5330e-04
# Epoch 75/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0111 - mse: 2.1569e-04 - val_loss: 0.0112 - val_mse: 1.6751e-04
# Epoch 76/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0108 - mse: 2.0665e-04 - val_loss: 0.0102 - val_mse: 1.5321e-04
# Epoch 77/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0104 - mse: 1.8920e-04 - val_loss: 0.0101 - val_mse: 1.5665e-04
# Epoch 78/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0112 - mse: 2.0099e-04 - val_loss: 0.0105 - val_mse: 1.6403e-04
# Epoch 79/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0112 - mse: 2.0208e-04 - val_loss: 0.0107 - val_mse: 1.6809e-04
# Epoch 80/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0107 - mse: 2.0344e-04 - val_loss: 0.0127 - val_mse: 2.3836e-04
# Epoch 81/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0115 - mse: 2.3275e-04 - val_loss: 0.0127 - val_mse: 2.3935e-04
# Epoch 82/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0106 - mse: 1.9984e-04 - val_loss: 0.0110 - val_mse: 1.7843e-04
# Epoch 83/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0106 - mse: 1.7773e-04 - val_loss: 0.0111 - val_mse: 1.6637e-04
# Epoch 84/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0113 - mse: 1.9365e-04 - val_loss: 0.0110 - val_mse: 1.6354e-04
# Epoch 85/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0108 - mse: 1.8539e-04 - val_loss: 0.0108 - val_mse: 1.7286e-04
# Epoch 86/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0106 - mse: 1.9626e-04 - val_loss: 0.0129 - val_mse: 2.3200e-04
# Epoch 87/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0116 - mse: 2.3055e-04 - val_loss: 0.0122 - val_mse: 2.0241e-04
# Epoch 88/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0102 - mse: 1.8715e-04 - val_loss: 0.0095 - val_mse: 1.2716e-04
# Epoch 89/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0100 - mse: 1.5881e-04 - val_loss: 0.0095 - val_mse: 1.5627e-04
# Epoch 90/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0117 - mse: 1.9925e-04 - val_loss: 0.0093 - val_mse: 1.6303e-04
# Epoch 91/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0111 - mse: 1.8591e-04 - val_loss: 0.0081 - val_mse: 1.0848e-04
# Epoch 92/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0097 - mse: 1.6567e-04 - val_loss: 0.0097 - val_mse: 1.2248e-04
# Epoch 93/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0112 - mse: 2.1475e-04 - val_loss: 0.0101 - val_mse: 1.2660e-04
# Epoch 94/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0105 - mse: 1.9062e-04 - val_loss: 0.0068 - val_mse: 8.8234e-05
# Epoch 95/500
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0093 - mse: 1.3882e-04 - val_loss: 0.0095 - val_mse: 1.4727e-04
# Epoch 96/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0109 - mse: 1.7171e-04 - val_loss: 0.0102 - val_mse: 1.6511e-04
# Epoch 97/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0106 - mse: 1.6811e-04 - val_loss: 0.0075 - val_mse: 1.0234e-04
# Epoch 98/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0093 - mse: 1.5049e-04 - val_loss: 0.0083 - val_mse: 1.0391e-04
# Epoch 99/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0104 - mse: 1.8363e-04 - val_loss: 0.0093 - val_mse: 1.1877e-04
# Epoch 100/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0100 - mse: 1.6987e-04 - val_loss: 0.0078 - val_mse: 9.8225e-05
# Epoch 101/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0093 - mse: 1.3751e-04 - val_loss: 0.0094 - val_mse: 1.4277e-04
# Epoch 102/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0108 - mse: 1.7193e-04 - val_loss: 0.0104 - val_mse: 1.7073e-04
# Epoch 103/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0110 - mse: 1.7729e-04 - val_loss: 0.0086 - val_mse: 1.2723e-04
# Epoch 104/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0095 - mse: 1.4823e-04 - val_loss: 0.0087 - val_mse: 1.1326e-04
# Epoch 105/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0103 - mse: 1.8032e-04 - val_loss: 0.0114 - val_mse: 1.6523e-04
# Epoch 106/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0117 - mse: 2.2068e-04 - val_loss: 0.0099 - val_mse: 1.2799e-04
# Epoch 107/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0096 - mse: 1.5916e-04 - val_loss: 0.0068 - val_mse: 9.0554e-05
# Epoch 108/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0092 - mse: 1.2898e-04 - val_loss: 0.0108 - val_mse: 1.7988e-04
# Epoch 109/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0109 - mse: 1.7055e-04 - val_loss: 0.0117 - val_mse: 2.0653e-04
# Epoch 110/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0105 - mse: 1.6171e-04 - val_loss: 0.0080 - val_mse: 1.1874e-04
# Epoch 111/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0094 - mse: 1.3998e-04 - val_loss: 0.0079 - val_mse: 9.3296e-05
# Epoch 112/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0106 - mse: 1.9223e-04 - val_loss: 0.0100 - val_mse: 1.2117e-04
# Epoch 113/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0104 - mse: 1.8274e-04 - val_loss: 0.0070 - val_mse: 8.5452e-05
# Epoch 114/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0086 - mse: 1.1935e-04 - val_loss: 0.0081 - val_mse: 1.1926e-04
# Epoch 115/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0095 - mse: 1.3538e-04 - val_loss: 0.0091 - val_mse: 1.4516e-04
# Epoch 116/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0097 - mse: 1.4205e-04 - val_loss: 0.0079 - val_mse: 1.1070e-04
# Epoch 117/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0085 - mse: 1.2647e-04 - val_loss: 0.0087 - val_mse: 1.0865e-04
# Epoch 118/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0097 - mse: 1.5660e-04 - val_loss: 0.0106 - val_mse: 1.4250e-04
# Epoch 119/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0104 - mse: 1.7347e-04 - val_loss: 0.0089 - val_mse: 1.0846e-04
# Epoch 120/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0085 - mse: 1.2179e-04 - val_loss: 0.0072 - val_mse: 1.0563e-04
# Epoch 121/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0087 - mse: 1.1528e-04 - val_loss: 0.0099 - val_mse: 1.7156e-04
# Epoch 122/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0097 - mse: 1.3820e-04 - val_loss: 0.0095 - val_mse: 1.6494e-04
# Epoch 123/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0089 - mse: 1.2101e-04 - val_loss: 0.0066 - val_mse: 1.0356e-04
# Epoch 124/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0084 - mse: 1.1722e-04 - val_loss: 0.0077 - val_mse: 1.0011e-04
# Epoch 125/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0086 - mse: 1.2623e-04 - val_loss: 0.0078 - val_mse: 1.0419e-04
# Epoch 126/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0080 - mse: 1.0655e-04 - val_loss: 0.0078 - val_mse: 1.1582e-04
# Epoch 127/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0084 - mse: 1.1392e-04 - val_loss: 0.0087 - val_mse: 1.3419e-04
# Epoch 128/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0087 - mse: 1.2090e-04 - val_loss: 0.0078 - val_mse: 1.1669e-04
# Epoch 129/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0079 - mse: 1.0966e-04 - val_loss: 0.0079 - val_mse: 1.0793e-04
# Epoch 130/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0080 - mse: 1.1230e-04 - val_loss: 0.0074 - val_mse: 1.0285e-04
# Epoch 131/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0074 - mse: 9.9606e-05 - val_loss: 0.0073 - val_mse: 1.1978e-04
# Epoch 132/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0080 - mse: 1.0043e-04 - val_loss: 0.0096 - val_mse: 1.7020e-04
# Epoch 133/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0087 - mse: 1.1548e-04 - val_loss: 0.0081 - val_mse: 1.4009e-04
# Epoch 134/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0077 - mse: 1.0075e-04 - val_loss: 0.0072 - val_mse: 1.0366e-04
# Epoch 135/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0077 - mse: 1.0836e-04 - val_loss: 0.0081 - val_mse: 1.0929e-04
# Epoch 136/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0075 - mse: 1.0485e-04 - val_loss: 0.0076 - val_mse: 1.0720e-04
# Epoch 137/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0071 - mse: 9.2167e-05 - val_loss: 0.0078 - val_mse: 1.1755e-04
# Epoch 138/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0073 - mse: 9.2387e-05 - val_loss: 0.0076 - val_mse: 1.1991e-04
# Epoch 139/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0071 - mse: 9.2946e-05 - val_loss: 0.0074 - val_mse: 1.1510e-04
# Epoch 140/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0072 - mse: 9.7279e-05 - val_loss: 0.0075 - val_mse: 1.1223e-04
# Epoch 141/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0067 - mse: 8.8054e-05 - val_loss: 0.0077 - val_mse: 1.1493e-04
# Epoch 142/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0068 - mse: 8.5581e-05 - val_loss: 0.0079 - val_mse: 1.1844e-04
# Epoch 143/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0068 - mse: 8.7576e-05 - val_loss: 0.0078 - val_mse: 1.1463e-04
# Epoch 144/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0067 - mse: 8.9711e-05 - val_loss: 0.0078 - val_mse: 1.1914e-04
# Epoch 145/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0065 - mse: 8.6731e-05 - val_loss: 0.0080 - val_mse: 1.2712e-04
# Epoch 146/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0065 - mse: 7.8698e-05 - val_loss: 0.0083 - val_mse: 1.3352e-04
# Epoch 147/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0067 - mse: 8.3220e-05 - val_loss: 0.0082 - val_mse: 1.2449e-04
# Epoch 148/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0065 - mse: 8.6135e-05 - val_loss: 0.0086 - val_mse: 1.2521e-04
# Epoch 149/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0067 - mse: 9.0953e-05 - val_loss: 0.0082 - val_mse: 1.2783e-04
# Epoch 150/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0061 - mse: 7.5169e-05 - val_loss: 0.0087 - val_mse: 1.4791e-04
# Epoch 151/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.
500
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0042 - mse: 2.9282e-05 - val_loss: 0.0112 - val_mse: 2.0813e-04
# Epoch 242/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0037 - mse: 3.1391e-05 - val_loss: 0.0100 - val_mse: 1.6261e-04
# Epoch 243/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0045 - mse: 4.0913e-05 - val_loss: 0.0094 - val_mse: 1.5233e-04
# Epoch 244/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0029 - mse: 2.3044e-05 - val_loss: 0.0097 - val_mse: 1.8749e-04
# Epoch 245/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0049 - mse: 3.5859e-05 - val_loss: 0.0091 - val_mse: 1.5291e-04
# Epoch 246/500
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0033 - mse: 2.6991e-05 - val_loss: 0.0098 - val_mse: 1.4598e-04
# Epoch 247/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0055 - mse: 4.7167e-05 - val_loss: 0.0097 - val_mse: 1.4447e-04
# Epoch 248/500
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0030 - mse: 2.3883e-05 - val_loss: 0.0097 - val_mse: 1.8524e-04
# Epoch 249/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0051 - mse: 3.6589e-05 - val_loss: 0.0096 - val_mse: 1.8199e-04
# Epoch 250/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0034 - mse: 2.3285e-05 - val_loss: 0.0096 - val_mse: 1.4549e-04
# Epoch 251/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0042 - mse: 3.3263e-05 - val_loss: 0.0095 - val_mse: 1.4592e-04
# Epoch 252/500
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0029 - mse: 2.2218e-05 - val_loss: 0.0095 - val_mse: 1.6907e-04
# Epoch 253/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0036 - mse: 2.3296e-05 - val_loss: 0.0090 - val_mse: 1.4909e-04
# Epoch 254/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0025 - mse: 2.0720e-05 - val_loss: 0.0089 - val_mse: 1.2700e-04
# Epoch 255/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0036 - mse: 2.7981e-05 - val_loss: 0.0085 - val_mse: 1.3176e-04
# Epoch 256/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0031 - mse: 2.2172e-05 - val_loss: 0.0093 - val_mse: 1.7196e-04
# Epoch 257/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0041 - mse: 2.6744e-05 - val_loss: 0.0087 - val_mse: 1.4176e-04
# Epoch 258/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0026 - mse: 2.1239e-05 - val_loss: 0.0085 - val_mse: 1.2499e-04
# Epoch 259/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0034 - mse: 2.6028e-05 - val_loss: 0.0085 - val_mse: 1.3777e-04
# Epoch 260/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0030 - mse: 2.0876e-05 - val_loss: 0.0091 - val_mse: 1.6270e-04
# Epoch 261/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0034 - mse: 2.2372e-05 - val_loss: 0.0084 - val_mse: 1.2322e-04
# Epoch 262/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0030 - mse: 2.3144e-05 - val_loss: 0.0083 - val_mse: 1.1933e-04
# Epoch 263/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0027 - mse: 2.0879e-05 - val_loss: 0.0088 - val_mse: 1.4842e-04
# Epoch 264/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0029 - mse: 1.9026e-05 - val_loss: 0.0088 - val_mse: 1.4578e-04
# Epoch 265/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0025 - mse: 1.9197e-05 - val_loss: 0.0085 - val_mse: 1.2793e-04
# Epoch 266/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0029 - mse: 2.3258e-05 - val_loss: 0.0087 - val_mse: 1.4504e-04
# Epoch 267/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0028 - mse: 1.8281e-05 - val_loss: 0.0091 - val_mse: 1.5859e-04
# Epoch 268/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0026 - mse: 1.7687e-05 - val_loss: 0.0083 - val_mse: 1.2272e-04
# Epoch 269/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0028 - mse: 2.1909e-05 - val_loss: 0.0084 - val_mse: 1.2907e-04
# Epoch 270/500
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0021 - mse: 1.6517e-05 - val_loss: 0.0093 - val_mse: 1.6085e-04
# Epoch 271/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0028 - mse: 1.7524e-05 - val_loss: 0.0086 - val_mse: 1.2959e-04
# Epoch 272/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.
500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0012 - mse: 3.0189e-06 - val_loss: 0.0099 - val_mse: 1.4645e-04
# Epoch 480/500
# 5/5 [==============================] - 0s 17ms/step - loss: 9.5104e-04 - mse: 1.8714e-06 - val_loss: 0.0095 - val_mse: 1.3926e-04
# Epoch 481/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0012 - mse: 2.3028e-06 - val_loss: 0.0094 - val_mse: 1.3415e-04
# Epoch 482/500
# 5/5 [==============================] - 0s 21ms/step - loss: 8.6946e-04 - mse: 1.2028e-06 - val_loss: 0.0097 - val_mse: 1.3940e-04
# Epoch 483/500
# 5/5 [==============================] - 0s 17ms/step - loss: 9.7787e-04 - mse: 1.5098e-06 - val_loss: 0.0101 - val_mse: 1.4750e-04
# Epoch 484/500
# 5/5 [==============================] - 0s 22ms/step - loss: 7.0821e-04 - mse: 8.9237e-07 - val_loss: 0.0105 - val_mse: 1.5506e-04
# Epoch 485/500
# 5/5 [==============================] - 0s 20ms/step - loss: 7.4056e-04 - mse: 8.2901e-07 - val_loss: 0.0107 - val_mse: 1.6300e-04
# Epoch 486/500
# 5/5 [==============================] - 0s 21ms/step - loss: 8.8752e-04 - mse: 1.2396e-06 - val_loss: 0.0105 - val_mse: 1.6084e-04
# Epoch 487/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0014 - mse: 2.7718e-06 - val_loss: 0.0104 - val_mse: 1.5800e-04
# Epoch 488/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0011 - mse: 1.5970e-06 - val_loss: 0.0101 - val_mse: 1.5152e-04
# Epoch 489/500
# 5/5 [==============================] - 0s 17ms/step - loss: 9.6567e-04 - mse: 1.4278e-06 - val_loss: 0.0099 - val_mse: 1.4069e-04
# Epoch 490/500
# 5/5 [==============================] - 0s 20ms/step - loss: 5.8737e-04 - mse: 5.3413e-07 - val_loss: 0.0098 - val_mse: 1.4284e-04
# Epoch 491/500
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0013 - mse: 2.5018e-06 - val_loss: 0.0098 - val_mse: 1.3914e-04
# Epoch 492/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0013 - mse: 2.5146e-06 - val_loss: 0.0099 - val_mse: 1.3878e-04
# Epoch 493/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0014 - mse: 2.9696e-06 - val_loss: 0.0100 - val_mse: 1.4003e-04
# Epoch 494/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0014 - mse: 2.6061e-06 - val_loss: 0.0101 - val_mse: 1.4180e-04
# Epoch 495/500
# 5/5 [==============================] - 0s 23ms/step - loss: 8.8159e-04 - mse: 1.1040e-06 - val_loss: 0.0101 - val_mse: 1.4129e-04
# Epoch 496/500
# 5/5 [==============================] - 0s 20ms/step - loss: 7.5423e-04 - mse: 1.0002e-06 - val_loss: 0.0102 - val_mse: 1.5356e-04
# Epoch 497/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0014 - mse: 2.9667e-06 - val_loss: 0.0102 - val_mse: 1.4664e-04
# Epoch 498/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0018 - mse: 4.7122e-06 - val_loss: 0.0102 - val_mse: 1.4773e-04
# Epoch 499/500
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0014 - mse: 2.8176e-06 - val_loss: 0.0104 - val_mse: 1.6186e-04
# Epoch 500/500
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0017 - mse: 4.2314e-06 - val_loss: 0.0104 - val_mse: 1.5225e-04

# %%
# make predictions
y_Pred = model.predict(training_images)
y_Pred

# %%
y

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y, y_Pred)
mse
# Out:
# 2.8695196177064684e-05

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y, y_Pred)
r2_score
# Out:
# 0.9506274877693949

# %%
model.save(datapath + '29thSept_CNN_Model_2_R2_0.95.h5')

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 58, 318, 64)       1792
#
#  max_pooling2d_5 (MaxPooling  (None, 29, 159, 64)      0
#  2D)
#
#  flatten_5 (Flatten)         (None, 295104)            0
#
#  dense_10 (Dense)            (None, 64)                18886720
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 18,888,577
# Trainable params: 18,888,577
# Non-trainable params: 0
# _________________________________________________________________

# %%
np.save(datapath + '29thSept_CNN_Model_2_R2_0.95_XTrain', X_Train)
np.save(datapath + '29thSept_CNN_Model_2_R2_0.95_yTrain', y_Train)
np.save(datapath + '29thSept_CNN_Model_2_R2_0.95_XValid', X_Valid)
np.save(datapath + '29thSept_CNN_Model_2_R2_0.95_yValid', y_Valid)

# %%
np.save(datapath + '29thSept_CNN_Model_2_R2_0.95_X', training_images)
np.save(datapath + '29thSept_CNN_Model_2_R2_0.95_y', y)

# %%
np.save(datapath + '29thSept_CNN_Model_2_R2_0.95_Loss', history.history['loss'])
np.save(datapath + '29thSept_CNN_Model_2_R2_0.95_ValLoss', history.history['val_loss'])

# %%
np.save(datapath + '29thSept_CNN_Model_2_R2_0.95_MSE', history.history['mse'])
np.save(datapath + '29thSept_CNN_Model_2_R2_0.95_ValMSE', history.history['val_mse'])

# %%
history.history['val_loss']

# %%
history.history['mse']

# %%
# make predictions
y_Pred = model.predict(X_Valid)
y_Pred

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_Valid, y_Pred)
r2_score
# Out:
# 0.7836096907893153

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_Valid, y_Pred)
mse
# Out:
# 0.00015225162047644548

# %%
# Load Model 1 and Preds
model1 = tf.keras.models.load_model(datapath + '28thSept_CNN_Model_4.h5')

# %%
y_Pred1 = model1.predict(training_images)
y_Pred1

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y, y_Pred1)
mse
# Out:
# 0.0009345477643667235

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y, y_Pred1)
r2_score
# Out:
# -0.6079684781231789

# %%
# summarize history for loss
plt.figure(facecolor='white')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model A Loss vs Epochs', fontsize=25, fontweight="bold",fontfamily="Arial")
plt.ylabel('Loss and Val_Loss', fontsize=22, fontweight="bold",fontfamily="Arial")
plt.xlabel('Epoch',fontsize= 22, fontweight="bold",fontfamily="Arial")
plt.xticks(fontsize=18,fontfamily="Arial", fontweight="bold")
plt.yticks(fontsize=18,fontfamily="Arial", fontweight="bold")
#plt.xlim([-50, 2050])
plt.ylim([0, 0.2])

plt.grid(color='black', linestyle='-.', linewidth=1)
plt.rcParams.update({'axes.linewidth': 3})
legend = plt.legend(['Train', 'Validation'], loc='upper left', prop={'size': 20,'family' : 'Arial', 'weight':'bold'})
fig = plt.gcf()
fig.set_size_inches(12, 8, forward=True)
ax = fig.gca()
ax.spines["top"].set_color("black")
ax.spines["left"].set_color("black")
ax.spines["right"].set_color("black")
ax.spines["bottom"].set_color("black")
ax.set_facecolor("white")
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('black')
plt.show()

# %%
testlen = 80
from sklearn.metrics import r2_score
plt.figure(facecolor='white')
plt.title('RA Values - Predicted vs Actual' + "R2 Score = {:.3f}".format(r2_score(y, y_Pred)), fontsize=25, fontweight="bold",fontfamily="Arial")
plt.plot(y_Pred, label = 'Predicted',marker = 'o',color ='r',linewidth=3)
plt.plot(y, label = 'Actual',linestyle = '--',marker = 'v',linewidth=3)

plt.xlabel('Test Cases', fontsize=22, fontweight="bold",fontfamily="Arial")
plt.ylabel('Ra', fontsize=22, fontweight="bold",fontfamily="Arial")
plt.xticks(np.arange(0, testlen+1, 4),fontsize=18,fontfamily="Arial", fontweight="bold")
plt.yticks(fontsize=18,fontfamily="Arial", fontweight="bold")
plt.xlim([0, testlen+1])

#plt.ylim([0, 400])
plt.grid(color='black',linestyle='-.',linewidth=1)
plt.rcParams.update({'axes.linewidth': 3})
plt.legend(loc='upper right',facecolor='white', edgecolor='black', prop={'size': 20,'family' : 'Arial','weight':'bold'})
fig = plt.gcf()
fig.set_size_inches(20,20, forward=True)
ax = fig.gca()
ax.spines["top"].set_color("black")
ax.spines["left"].set_color("black")
ax.spines["right"].set_color("black")
ax.spines["bottom"].set_color("black")
ax.set_facecolor("white")
plt.show()

# %%
model = tf.keras.models.load_model(datapath + '28thSept_CNN_Model.h5')

# %%
# !pip install lime

# %%
import lime
import lime.lime_tabular
from lime import lime_image

# %%
explainer = lime_image.LimeImageExplainer()

# %%
y_samp = [0.11375]

# %%
sample = []
for i in range(1, 2): # 81
  img = cv2.imread(datapath + f"Spectrograms/spectro_matplot_{i}.png")
  #imgg = img.flatten()
  sample.append(img)
print(sample)

# %%
from skimage.transform import resize
width, height = 512, 512
resized_sample = [resize(i, (width, height)) for i in sample]
training_images_sample = np.array(resized_sample)

# %%
pred = model.predict(training_images_sample)
pred
# Out:
# array([[0.11465628]], dtype=float32)

# %%
# !pip install shap

# %%
import shap

# %%
explainer = shap.DeepExplainer(model = model, data = training_images_sample)
shap_values = explainer.shap_values(training_images_sample)

shap_values = shap_values[0].reshape(-1)
X_test = training_images_sample.reshape(-1)

shap.summary_plot(shap_values, X_test)

# %%
explainer = lime_image.LimeImageExplainer(random_state=123)
explainer

# %%
explanation = explainer.explain_instance(training_images_sample, model.predict(training_images_sample), random_seed=123)
explanation
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-49fe674b3d0d> in <module>
# ----> 1 explanation = explainer.explain_instance(training_images_sample, model.predict(training_images_sample), random_seed=123)
#       2 explanation
#
# /usr/local/lib/python3.7/dist-packages/lime/lime_image.py in explain_instance(self, image, classifier_fn, labels, hide_color, top_labels, num_features, num_samples, batch_size, segmentation_fn, distance_metric, model_regressor, random_seed)
#     180                                                     random_seed=random_seed)
#     181         try:
# --> 182             segments = segmentation_fn(image)
#     183         except ValueError as e:
#     184             raise e
#
# /usr/local/lib/python3.7/dist-packages/lime/wrappers/scikit_image.py in __call__(self, *args)
#     115
#     116     def __call__(self, *args):
# --> 117         return self.target_fn(args[0], **self.target_params)
#
# /usr/local/lib/python3.7/dist-packages/skimage/segmentation/_quickshift.py in quickshift(image, ratio, kernel_size, max_dist, return_tree, sigma, convert2lab, random_seed)
#      66         raise ValueError("`kernel_size` should be >= 1.")
#      67
# ---> 68     image = ndi.gaussian_filter(image, [sigma, sigma, 0])
#      69     image = np.ascontiguousarray(image * ratio)
#      70
#
# /usr/local/lib/python3.7/dist-packages/scipy/ndimage/filters.py in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     333     output = _ni_support._get_output(output, input)
#     334     orders = _ni_support._normalize_sequence(order, input.ndim)
# --> 335     sigmas = _ni_support._normalize_sequence(sigma, input.ndim)
#     336     modes = _ni_support._normalize_sequence(mode, input.ndim)
#     337     axes = list(range(input.ndim))
#
# /usr/local/lib/python3.7/dist-packages/scipy/ndimage/_ni_support.py in _normalize_sequence(input, rank)
#      65         if len(normalized) != rank:
#      66             err = "sequence argument must have length equal to input rank"
# ---> 67             raise RuntimeError(err)
#      68     else:
#      69         normalized = [input] * rank
#
# RuntimeError: sequence argument must have length equal to input rank

# %%
img, mask = explanation.get_image_and_mask(Y_test[idx], positive_only=True, hide_rest=True)
img.shape, mask.shape

# %%
LX = np.load('markers_dataset_trial/LX.npy')
LY = np.load('markers_dataset_trial/LY.npy')

model = load_model('marker_model_fold_no_10.h5')
pred = model.predict(LX)

LY = np.array([1 if a == 0 else 0 for a in LY])  # reversing 0 and 1

from sklearn.preprocessing import OneHotEncoder
Y_new = OneHotEncoder().fit_transform(LY.reshape((-1,1))).toarray()

pred_class = [1 if a < 0.5 else 0 for a in pred]
correct_X_ind = list(np.where(pred_class==LY)[0])
len(correct_X_ind)

# %%
import lime
from lime import lime_image
from matplotlib import pyplot as plt
fname_out = 'C:\\Users\\data_and_code_Dec31\\Shallow_markers'

seg_fn = 'quickshift'
if seg_fn == 'quickshift':
    k_size = 5   # number of s-pixels
    num_s = 100   # number of perturbed samples
elif seg_fn == 'slic': 
    k_size = 200
    num_s = 400
    
explainer = lime_image.LimeImageExplainer()
score = []
# Input the sample_index corresponding to every image (from 1 to 123)
for sample_ind in correct_X_ind:

# sample_ind = 27
    sample = LX[sample_ind, :, :, :].astype('double')
    y_samp = LY[sample_ind]     # Change accordingly for different seg_fn
    explanation = explainer.explain_instance(sample, model, top_labels=2, hide_color=0, num_samples=num_s, num_features = k_size)
    score.append(explanation.score)

    if explanation.score > 0.75 and explanation.score <= 1:
        temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features = k_size, hide_rest=False)
        plt.figure(figsize = (12,8))
        plt.subplot(1, 2, 1)
        plt.imshow(sample)
        plt.subplot(1, 2, 2)
        plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
        if y_samp == 0:
          plt.suptitle('No marker',fontsize= 14, fontweight = 'bold')
        else:
          plt.suptitle('With marker',fontsize= 14, fontweight = 'bold')
        plt.savefig(fname_out+'\\local results\\'+str(sample_ind)+'_LIME_topten_plot.png',dpi = 400)
        plt.close()

        # save weights and watershed/lime ratios
        weightRatio = []
        for i, e in explanation.local_exp[explanation.top_labels[0]]:
            weightRatio.append((i, e, explanation.local_pred[explanation.top_labels[0]],explanation.intercept[explanation.top_labels[0]],explanation.top_labels[0]))
  
        WR = pd.DataFrame(weightRatio)
        WR.to_csv(fname_out+ str(sample_ind)+'_weightRatioPred_score'+str(round(explanation.score,2))+'_numseg'+str(len(explanation.local_exp[explanation.top_labels[0]]))+'.csv', index = False)
        
            
score = np.array(score)
np.save(fname_out+'\\'+seg_fn+'kerns'+str(k_size)+'_nums'+str(num_s)+'score.npy',score)
